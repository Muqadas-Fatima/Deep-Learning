# %%
import numpy as np

#z1=w1x1+w2x2+b1
#a1=sigmoid(z1)
#z2=w1a1+b1
#a2=y_pred=sigmoid(z2)
# dl/dw

# %%
def predict(weights, biases, f):
    return np.dot(f, weights) + biases

# features (x valyes)
features = np.random.randint(low=1, high=10, size=(1,3))
# y target all rows but only third column means last column
y=features[:,-1]
# features
X = features[:, :2]

weights= np.random.rand(2)  #dim (3,1)
z1=predict(weights,0,X)
a1 = 1 / (1 + np.exp(-z1))
z2=predict(0.1,0,a1)
a2=  1 / (1 + np.exp(-z2))



# wnew=wold - 0.1(dl/dw)
# w1= dz1/dw1 * da1/dz1 * dz2/da1 * da2/dz2 * dl/da2
# same for weight 2 of layer 1
# for layer 2 weights it would be
# w2_l2= dz2/da1 * da2/dz2 * dl/da2
# we diffrentiate loss wrt. weights because we want such weights where error is zero and it can be found because of the slope
# Out:
# array([0.52490222])
